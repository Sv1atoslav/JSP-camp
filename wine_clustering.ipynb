# %%
import pandas as pd

data = pd.read_csv('wine.csv')

# %%
X = data[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
          'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
          'pH', 'sulphates']]
X.shape
# Out:
# (1599, 10)

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=3)
# model.fit(X)

# %%
from yellowbrick.cluster import KElbowVisualizer

visualizer = KElbowVisualizer(model, k=(2,13))

visualizer.fit(X)    # Fit the data to the visualizer
visualizer.poof()    # Draw/show/poof the data

# %%
model.predict(X[1500:1600])
# Out:
# array([4, 1, 1, 4, 4, 4, 4, 4, 4, 4, 1, 0, 4, 1, 1, 1, 1, 0, 4, 4, 0, 4,
#        1, 1, 0, 0, 0, 4, 1, 1, 4, 0, 4, 3, 0, 0, 0, 0, 4, 1, 0, 0, 0, 4,
#        4, 0, 4, 4, 0, 4, 4, 0, 1, 0, 4, 4, 4, 4, 2, 2, 2, 2, 4, 4, 4, 0,
#        1, 4, 0, 0, 0, 4, 3, 0, 3, 4, 0, 4, 4, 0, 4, 0, 4, 3, 0, 0, 1, 0,
#        3, 3, 0, 4, 0, 0, 0, 1, 0, 0, 0])

# %%
from sklearn.cluster import MeanShift
import numpy as np

clustering = MeanShift(bandwidth=2)
clustering = clustering.fit(X)

# %%
clustering.predict(X[1500:1600])
# Out:
# array([  3, 386,  64,   3,   0,   0,   3,   0,   9,   8, 472,  30,  21,
#        471, 223, 223,  61, 129,   8,   7, 129,   4,  61, 451,  63,  28,
#         29,   9, 383, 428,  21,   7, 422, 119,  12,  20,  38, 130,   9,
#        124, 477,  33, 227, 148,  15,  30,  30,   7, 144,   9,  30,  30,
#        473,  30,   9,   9,  15,   9, 443, 117, 117, 117,  15,  15,  15,
#         53,  66,  15, 127,  20,  28,   9, 193,  84, 492,  15,  35, 476,
#         15, 235,  19, 235,   7, 478, 455,  63, 124,  30, 417, 457,  68,
#          9, 234, 227, 236, 484, 234, 236,  54], dtype=int64)

# %%
from sklearn.cluster import DBSCAN

cluster = DBSCAN(eps=3, min_samples=2)
cluster.fit(X)
# Out:
# DBSCAN(algorithm='auto', eps=3, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=2, n_jobs=None, p=None)

# %%
cluster.labels_
# Out:
# array([ 0,  0,  0, ..., 71,  0,  0], dtype=int64)

# %%
MeanShift?

# %%
KMeans?

# %%
DBSCAN?

# %%
import cv2
